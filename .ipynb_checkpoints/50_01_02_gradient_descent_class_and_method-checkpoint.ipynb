# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt 
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [34.09408819]
# -1.9271199444619507

# %%
m = 34.09

# %%
class GDRegressor:

    def __init__(self, learning_rate , epochs) : 
        self.m = 29.19 
        self.b = -120 
        self.lr = learning_rate
        self.epochs = epochs 

    def fit(self,X,y): 
        # calculate the b using GD 
        for i in range(self.epochs): 
            loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
            self.b = self.b - (self.lr * loss_slope)
            print(loss_slope,self.b)

        print(self.b)

# %%
gd = GDRegressor(0.001,23)

# %%
gd.fit(X,y)
# Out:
# -23754.872613405634 -96.24512738659436
# -19003.898090724502 -77.24122929586986
# -15203.118472579603 -62.03811082329025
# -12162.494778063683 -49.87561604522657
# -9729.995822450945 -40.14562022277563
# -7783.996657960758 -32.36162356481487
# -6227.197326368606 -26.134426238446263
# -4981.757861094884 -21.15266837735138
# -3985.4062888759076 -17.16726208847547
# -3188.3250311007264 -13.978937057374745
# -2550.6600248805803 -11.428277032494165
# -2040.5280199044646 -9.387749012589701
# -1632.4224159235716 -7.75532659666613
# -1305.9379327388574 -6.449388663927273
# -1044.750346191086 -5.404638317736187
# -835.8002769528688 -4.5688380407833185
# -668.6402215622952 -3.9001978192210234
# -534.9121772498362 -3.3652856419711874
# -427.92974179986885 -2.9373559001713185
# -342.3437934398953 -2.5950121067314234
# -273.87503475191625 -2.321137071979507
# -219.10002780153292 -2.1020370441779743
# -175.2800222412265 -1.9267570219367478
# -1.9267570219367478
