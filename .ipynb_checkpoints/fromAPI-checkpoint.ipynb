# %%
import pandas as pd

import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=7f28078657cb5b626069772944e5e88f')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 178.764,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.707,
#    'vote_count': 27189},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 178.764,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.707,
#   'vote_count': 27189},
#  {'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  [18, 80]  278                en
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg  [18, 80]  238                en
#
#              original_title  \
# 0  The Shawshank Redemption
# 1             The Godfather
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     178.764
# 1  Spanning the years 1945 to 1955, a chronicle o...     179.773
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
#
#    video  vote_average  vote_count
# 0  False         8.707       27189
# 1  False         8.689       20657

# %%
pd.DataFrame(response.json()['results']).head(2)[['id','title','overview','release_date','vote_average','vote_count']]
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
#
#                                             overview release_date  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
#
#    vote_average  vote_count
# 0         8.707       27189
# 1         8.689       20657

# %%
df.head()

# %%
df =  pd.DataFrame()

# %%
df

# %%
for i in range(1,50):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=7f28078657cb5b626069772944e5e88f&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','vote_average','vote_count']]
    df = pd.concat([temp_df,df], ignore_index=True)

# %%
df
# Out:
#          id                                        title  \
# 0       981                       The Philadelphia Story
# 1       702                     A Streetcar Named Desire
# 2    841755  Mortal Kombat Legends: Battle of the Realms
# 3    283995               Guardians of the Galaxy Vol. 2
# 4       746                             The Last Emperor
# ..      ...                                          ...
# 975     346                                Seven Samurai
# 976     769                                   GoodFellas
# 977   12477                       Grave of the Fireflies
# 978   11216                              Cinema Paradiso
# 979     637                            Life Is Beautiful
#
#                                               overview release_date  \
# 0    When a rich woman's ex-husband and a tabloid-t...   1940-12-05
# 1    A fading southern belle moves in with her sist...   1951-09-19
# 2    The Earthrealm heroes must journey to the Outw...   2021-08-30
# ...

# %%
df.shape
# Out:
# (980, 6)

# %%
df.to_csv('movie.csv')

# %%
print("KAynat")

# %%
print("KAynat")
